# %% [markdown]
# ![Logo UOC](https://www.uoc.edu/portal/_resources/common/imatges/marca_UOC/logotips/logo-UOC-2linies.png)
#
# # TFG - Inteligencia Artificial
# Enero de 2026
#
# ## Predicción de Respuesta a Tratamientos Oncológicos Basada en el Perfil Genético Mediante Técnicas de Aprendizaje Automático (ML) e Identificación de Genes Candidatos a Biomarcador Usando Técnicas de Explicabilidad (XAI) y Cuantificación de la Incertidumbre (UQ)
#
# ---
#
# #### Pablo Vázquez Rodríguez
# ##### Grado en Ingeniería Informática
# ##### Inteligencia Artificial
#
# #### Dra. María Moreno de Castro
# #### Dr. Friman Sánchez
#
# ---

# %% [markdown]
# ## Modelado (Paso 1): Selección de características supervisada
# Como ya se comentó en el documento de exploración y preparación de datos durante el modelado se harán dos tareas:
# 1. Selección de características supervisada
# 2. Entrenamiento de modelos, comparaciones y selección del modelo óptimo
#
# Durante la primera tarea se realizará una selección de genes basada en modelos de regresión logística, Random Forest, XGBoost y CatBoost, modelados sobre el conjunto de datos reducido (el filtrado mediante varianza y análisis DEG).
#
# Durante la segunda tarea, y se entrenarán los modelos de nuevo esta vez sobre el conjunto que contiene sólo a los genes seleccionados. Tras el entrenamiento se evaluarán para elegir el modelo óptimo, sobre el que más adelante se aplicarán técnicas de explicabilidad y cuantificación de la incertidumbre.

# %% [markdown]
# ## 0. Operaciones previas

# %% [markdown]
# ### Carga de módulos necesarios

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import optuna
from sklearn.base import clone
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import get_scorer
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from kneed import KneeLocator

# %% [markdown]
# ### Configuraciones iniciales

# %%
# Random generator de numpy con seed para reproducibilidad en el notebook
rng_seed = 19293
rng = np.random.default_rng(seed=rng_seed)

# %%
# Carga de los datasets
df_full = pd.read_csv("./data/full_top_significance_dataset.csv")
df_train = pd.read_csv("./data/train_dataset.csv")
df_test = pd.read_csv("./data/test_dataset.csv")
df_cal = pd.read_csv("./data/calibration_dataset.csv")

# %%
# VARIABLES ÚTILES

# Nombres de las columnas de genes
gene_columns = df_full.columns.difference(["Sample_id", "Response"])

# %% [markdown]
# ### Funciones auxiliares

# %% [markdown]
# **train_with_cv**
#
# Como se usarán búsquedas de hiperparámetros, validación cruzada estratificada y siempre se usarán alguno de los siguientes algoritmos: Regresión Logística, Random Forest, XGBoost y CatBoost, se define una función auxiliar que permite:
#
# - Pasar un estimador de alguno de los algoritmos ya mencionados junto con la rejilla de parámetros a explorar
# - Configurar el número de splits de la validación cruzada
# - Definir el número de iteraciones del estudio de búsqueda de hiperparámetros
# - Detener las iteraciones internas cuando llega a 50 rondas sin mejorar la métrica objetivo (AUC). Sólo en XGBoost y CatBoost
# - Obtener un modelo entrenado con los mejores hiperparámetros encontrados
#
# Para la búsqueda de hiperparámetros se usa Optuna [https://optuna.org/] en lugar de los habituales GridSearchCV o RandomizedSearchCV. La razón es porque Optuna es mucho más eficiente, ya que optimiza la búsqueda de hiperparámetros teniendo en cuenta la información de iteraciones previas, tratando de maximizar la probabilidad de mejora de la métrica objetivo en cada iteración. (Ver: Tree-structured Parzen Estimator).
#
# Mientras que para GridSearchCV se le pasan valores concretos a explorar en el grid, a Optuna se le pasan rangos que el algoritmo explorará. Esto permite que el algoritmo se adapte a valores más optimizados y con menos riesgo de sesgos por elección arbitraria de estos. Gracias a eso, es mucho más eficiente a la hora de explorar espacios de hiperparámetros más grandes que de otro modo serían inabarcables o requerirían de mucho tiempo y capacidad de cómputo.
#
# Los algoritmos más pesados de los usados (XGBoost y CatBoost), en igualdad de condiciones con Optuna van mucho más rápido que los algoritmos ligeros (Regresión Logística y Random Forest). Esa ilusión es posible que se deba a que con XGBoost y CatBoost se usa early stopping, que además de mitigar problemas de sobreajuste hace que si el modelo, en iteraciones internas no mejora la métrica en 50 rondas, directamente pasa a la siguiente sin llegar a gastar todas las rondas que se hubiesen configurado para cada iteración.

# %%
def train_with_cv(original_estimator, param_grid, X_train, y_train, scoring="roc_auc",
                  n_splits=5, n_trials=30):
    """
    Entrena un modelo con validación cruzada y búsqueda de hiperparámetros.

    Parámetros
    ----------
    original_estimator : sklearn estimator
        Modelo base (LogisticRegression, RandomForestClassifier, XGBClassifier, CatBoost)
    param_grid : dict
        Diccionario con los hiperparámetros a explorar.
    X_train : array-like
        Matriz de entrenamiento.
    y_train : array-like
        Etiquetas de entrenamiento.
    scoring : callable o str
        Métrica de evaluación (por defecto AUCROC).
    n_splits : int
        Número de folds para StratifiedKFold.
    n_trials: int
        Número de trials para optimizar hiperparámetros

    Return
    ------
    study_results : dict
        Diccionario con: Objeto de estudio, mejores parámetros, mejor puntuación de métrica, 
        modelo entrenado con los mejores parámetros hallados
    """
    scorer = get_scorer(scoring)

    def objective(trial):
        # Construir kwargs del estimador a partir de la rejilla de parámetros
        # En base al primer elemento del espacio:
        #    "I": Espacio de enteros
        #    "F": Espacio de floats
        #    En cualquier otro caso: Espacio de categorías
        params = {}
        for name, space in param_grid.items():
            match space[0]:
                case "I":
                    params[name] = trial.suggest_int(name, min(space[1:]), max(space[1:]))
                case "F":
                    params[name] = trial.suggest_float(name, min(space[1:]), max(space[1:]))
                case _:
                    params[name] = trial.suggest_categorical(name, space[1:])

        # Clonar el estimador origen y actualizarlo con los hiperparámetros en cada iteración
        model = clone(original_estimator)
        model.set_params(**params, random_state=rng_seed)

        # Crear los folds para la validación cruzada
        cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=rng_seed)
        scores = []

        # Recorrer todos los folds de validación cruzada
        #
        # NOTA: Se tratan por separado los conjuntos de train y val de cada fold
        # para poder aprovecharse de la evaluación con early_stopping que 
        # XGBoost y CatBoost permiten definir para ahorrar creaciones de árboles 
        # innecesarias si no hay mejoras
        for train_idx, valid_idx in cv.split(X_train, y_train):
            X_tr, X_val = X_train.iloc[train_idx], X_train.iloc[valid_idx]
            y_tr, y_val = y_train[train_idx], y_train[valid_idx]

            # Ajuste con soporte de eval_set y early stopping
            # Si los estimadores lo permiten, se usa early stopping
            #
            # NOTA: XGBClassifier da problemas si se le pasa el parámetro
            #       early_stopping_rounds en el fit, así que hay que 
            #       tratarlo a parte
            if isinstance(model, XGBClassifier):
                model.set_params(early_stopping_rounds=50)
                model.fit(X_tr, y_tr, eval_set=[(X_val, y_val)], verbose=False)
            elif isinstance(model, CatBoostClassifier):
                model.fit(X_tr, y_tr, eval_set=[(X_val, y_val)], early_stopping_rounds=50, 
                          verbose=False)
            else:
                # Modelos que no soportan early stopping
                model.fit(X_tr, y_tr)

            # Se acumulan los scores de cada iteración para devolver la media al acabar todas las iteraciones sobre los kfolds
            preds = model.predict_proba(X_val)[:, 1] if hasattr(model, "predict_proba") else model.predict(X_val)
            scores.append(scorer._score_func(y_val, preds))

        return np.mean(scores)

    # Crear estudio y optimizar
    study = optuna.create_study(direction="maximize")
    study.optimize(objective, n_trials=n_trials)

    best_params = study.best_params
    best_score = study.best_value

    # Reentrenar con los mejores hiperparámetros y todos los datos de train
    best_model = clone(original_estimator)
    best_model = best_model.set_params(**best_params, random_state=rng_seed)

    if isinstance(best_model, (XGBClassifier, CatBoostClassifier)):       
        best_model.fit(X_train, y_train, verbose=False)
    else:
        best_model.fit(X_train, y_train)

    study_results = {
        "study": study,
        "best_params": best_params,
        "best_score": best_score,
        "best_model": best_model
    }
    
    return study_results

# %% [markdown]
# ### 1. Selección de características supervisada

# %% [markdown]
# Como para la regresión logística se necesita trabajar con los datos escalados y teniendo en cuenta que a los algoritmos de árboles no les afecta si está o no escalado el dataset, usaremos el dataset escalado para todos los modelos.
#
# Además, como en este caso se quieren modelos sólo para valorar las características más importantes y estables entre ellos, vamos a explorar espacios relativamente grandes de hiperparámetros pero con relativamente pocas iteraciones de Optuna, ya que buscamos estabilidad de features y no tanto optimización de modelos.

# %%
# Escalado de los datasets

# Separar features y etiquetas
X_train = df_train[gene_columns]
y_train = df_train["Response"]

X_test = df_test[gene_columns]
y_test = df_test["Response"]

X_cal = df_cal[gene_columns]
y_cal = df_cal["Response"]

# Ajustar escalador con el dataset de train y aplicar a todos el mismo scaler
scaler = StandardScaler().set_output(transform='pandas')
scaler.fit(X_train)

# Transformar subconjuntos
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_cal_scaled = scaler.transform(X_cal)

# Reconstruir dataframes escalados
df_scaled_train = pd.concat([X_train_scaled, df_train[["Sample_id", "Response"]]], axis=1)
df_scaled_test = pd.concat([X_test_scaled, df_test[["Sample_id", "Response"]]], axis=1)
df_scaled_cal = pd.concat([X_cal_scaled, df_cal[["Sample_id", "Response"]]], axis=1)

# %%
df_scaled_train.head()
# Out:
#      ACADSB     ACSL5     ACTG2      AFF4      AIDA     ALPK1   ANAPC10  \
# 0  1.231558  0.942470  0.320343  0.746647  1.459748  0.438777  0.749312
# 1 -0.109145 -0.964638 -0.760699 -1.022417 -0.693688 -0.771081 -0.632483
# 2  0.817698 -0.321584  0.823303 -0.033918 -0.561066  2.861137  0.497864
# 3 -0.251677  0.502311 -0.448509  0.441671 -0.430611 -0.857973  0.547046
# 4 -0.424320 -0.353052 -0.912005 -1.471639 -0.599881 -0.978137 -0.303549
#
#        ANKH   APBB1IP  ARHGEF26  ...   ZKSCAN1     ZNF12    ZNF254    ZNF322  \
# 0  0.545361  1.446620  1.293439  ...  0.932296  0.340859  0.591818  1.566404
# 1 -1.210308 -1.184311 -1.079429  ... -0.604239 -0.778494 -1.067292 -0.453361
# 2  0.310249  0.397984  0.675382  ...  1.552688 -0.029229  0.736610 -0.078645
# 3 -0.118640 -0.902618 -0.685264  ... -0.609098 -0.627500  0.692641 -1.034946
# 4 -1.269137 -1.081266 -0.806856  ... -0.554699 -0.137442 -1.199459 -0.882832
#
#      ZNF362    ZNF37A    ZNF493    ZNF770       Sample_id      Response
# 0  1.679017  1.239448  0.881952  1.593512       GSM158252      Response
# 1 -1.150068 -1.250517 -1.128734 -1.265575       GSM508120  Non_response
# 2  0.251776  0.694699  0.956896  0.423625      GSM2804900      Response
# 3 -0.500763 -0.077298 -0.472221  0.204125  GSM2193370--22      Response
# 4 -1.245343 -1.228402 -1.157375 -1.519534       GSM505471  Non_response
#
# [5 rows x 325 columns]

# %%
# Datos de entrenamiento para selección de genes
X_train = df_scaled_train.drop(columns=["Response", "Sample_id"])
y_train = df_scaled_train["Response"]

# %% [markdown]
# **Regresión logística**:
# * La clase es de tipo categórico, pero scikit learn la transforma automáticamente en LogisticRegression.
# * Balanceada para paliar la asimetría del dataset
# * Uso de elasticnet como método de regularización para mitigar correlaciones y por la complejidad del dataset
# * Hiperparámetros:
#     * **solver=saga**: Es el único que soporta elasticnet
#     * **l1_ration**: Regularización Elasticnet: Balanceo de la regularización entre L1 y L2. Rango: \[0-1\]
#     * **C**: Inverso de la regularización: Fuerza de la regularización aplicada. Valores pequeños (ej. 0.1) implican regularización fuerte, valores grandes (ej. 10, 100) implican regularización débil.
#
# **NOTA**: La función auxiliar train_with_cv() incluye validación cruzada estratificada y un grid para ajustar la búsqueda de los mejores hiperparámetros.
#
# Se evalúan los espacios de hiperparámetros siguientes:
# * **C**: 0.01 a 10
# * **l1_ratio**: 0.1 a 0.9

# %%
# NOTA: Esta celda tarda alrededor de 15 minutos en el hardware original usado
# Modelo de Regresión logística para selección de genes

# Estimador
log_reg = LogisticRegression(penalty="elasticnet", solver="saga", max_iter=5000, class_weight="balanced")

# Rangos de hiperparámetros
log_reg_param_grid = {"C": ["F", 0.01, 10], "l1_ratio": ["F", 0.1, 0.9]}

# Entrenamiento con validación cruzada
log_reg_results = train_with_cv(log_reg, log_reg_param_grid, X_train, y_train,
                  scoring="roc_auc", n_splits=5)

print("Mejores parámetros: ", log_reg_results["best_params"], "\nMejor ROC_AUC=", log_reg_results["best_score"])
# Out:
# [I 2025-11-27 03:21:33,536] A new study created in memory with name: no-name-dbe766dc-2b5a-4a09-ac11-8d664eac79b4
# [I 2025-11-27 03:22:15,711] Trial 0 finished with value: 0.661552980196473 and parameters: {'C': 3.67684969259237, 'l1_ratio': 0.8761396588460734}. Best is trial 0 with value: 0.661552980196473.
# [I 2025-11-27 03:22:52,907] Trial 1 finished with value: 0.6624099581083516 and parameters: {'C': 3.304000095043685, 'l1_ratio': 0.40222103073447646}. Best is trial 1 with value: 0.6624099581083516.
# [I 2025-11-27 03:23:33,469] Trial 2 finished with value: 0.6614595636855547 and parameters: {'C': 3.722183872911723, 'l1_ratio': 0.5143839090859783}. Best is trial 1 with value: 0.6624099581083516.
# [I 2025-11-27 03:24:18,294] Trial 3 finished with value: 0.6585072915559831 and parameters: {'C': 5.775635673943065, 'l1_ratio': 0.40669175360547105}. Best is trial 1 with value: 0.6624099581083516.
# [I 2025-11-27 03:24:32,066] Trial 4 finished with value: 0.6916362364897595 and parameters: {'C': 0.4306729273093262, 'l1_ratio': 0.3331177871427863}. Best is trial 4 with value: 0.6916362364897595.
# [I 2025-11-27 03:25:17,455] Trial 5 finished with value: 0.6577920228432081 and parameters: {'C': 6.041207722331309, 'l1_ratio': 0.651547633824406}. Best is trial 4 with value: 0.6916362364897595.
# [I 2025-11-27 03:26:00,773] Trial 6 finished with value: 0.6584540385325142 and parameters: {'C': 6.0760259302174635, 'l1_ratio': 0.24094772067381945}. Best is trial 4 with value: 0.6916362364897595.
# [I 2025-11-27 03:26:51,439] Trial 7 finished with value: 0.6554241736866789 and parameters: {'C': 9.499264390853014, 'l1_ratio': 0.8375445030374528}. Best is trial 4 with value: 0.6916362364897595.
# [I 2025-11-27 03:27:13,720] Trial 8 finished with value: 0.682763902584422 and parameters: {'C': 0.9268692612466553, 'l1_ratio': 0.6093341440777373}. Best is trial 4 with value: 0.6916362364897595.
# [I 2025-11-27 03:27:48,158] Trial 9 finished with value: 0.6656816987582737 and parameters: {'C': 2.5543883730243224, 'l1_ratio': 0.6942735537942509}. Best is trial 4 with value: 0.6916362364897595.
# [I 2025-11-27 03:27:51,951] Trial 10 finished with value: 0.6974642557281265 and parameters: {'C': 0.06530850310086017, 'l1_ratio': 0.14605252074281166}. Best is trial 10 with value: 0.6974642557281265.
# [I 2025-11-27 03:28:04,475] Trial 11 finished with value: 0.688741751667376 and parameters: {'C': 0.40055230355847193, 'l1_ratio': 0.10074013111883257}. Best is trial 10 with value: 0.6974642557281265.
# [I 2025-11-27 03:28:30,143] Trial 12 finished with value: 0.6709434834899886 and parameters: {'C': 1.5439601200835644, 'l1_ratio': 0.21062617416888324}. Best is trial 10 with value: 0.6974642557281265.
# [I 2025-11-27 03:28:39,968] Trial 13 finished with value: 0.6968559447796108 and parameters: {'C': 0.2470923524328343, 'l1_ratio': 0.2596431141722224}. Best is trial 10 with value: 0.6974642557281265.
# [I 2025-11-27 03:29:26,576] Trial 14 finished with value: 0.6571955574970275 and parameters: {'C': 8.250314212446023, 'l1_ratio': 0.15069433549998465}. Best is trial 10 with value: 0.6974642557281265.
# [I 2025-11-27 03:29:54,589] Trial 15 finished with value: 0.6692264049991419 and parameters: {'C': 1.7590630783664953, 'l1_ratio': 0.2543536170337806}. Best is trial 10 with value: 0.6974642557281265.
# [I 2025-11-27 03:30:00,178] Trial 16 finished with value: 0.6961122264308359 and parameters: {'C': 0.10972564900209139, 'l1_ratio': 0.32740789201418385}. Best is trial 10 with value: 0.6974642557281265.
# [I 2025-11-27 03:30:30,381] Trial 17 finished with value: 0.6667845631765172 and parameters: {'C': 2.1262649323414196, 'l1_ratio': 0.17941549637860227}. Best is trial 10 with value: 0.6974642557281265.
# [I 2025-11-27 03:31:10,149] Trial 18 finished with value: 0.6604281595787257 and parameters: {'C': 4.7159737263111765, 'l1_ratio': 0.10692947352559784}. Best is trial 10 with value: 0.6974642557281265.
# [I 2025-11-27 03:31:33,362] Trial 19 finished with value: 0.6751139653714185 and parameters: {'C': 1.1812238811227682, 'l1_ratio': 0.30548551082787406}. Best is trial 10 with value: 0.6974642557281265.
# [I 2025-11-27 03:32:09,940] Trial 20 finished with value: 0.663401323634415 and parameters: {'C': 2.9885524669417305, 'l1_ratio': 0.46976396790017794}. Best is trial 10 with value: 0.6974642557281265.
# [I 2025-11-27 03:32:14,548] Trial 21 finished with value: 0.69274950238375 and parameters: {'C': 0.0853081245716126, 'l1_ratio': 0.3247166177779263}. Best is trial 10 with value: 0.6974642557281265.
# [I 2025-11-27 03:32:36,763] Trial 22 finished with value: 0.6768539291621687 and parameters: {'C': 1.0651120643389578, 'l1_ratio': 0.2709147903829326}. Best is trial 10 with value: 0.6974642557281265.
# [I 2025-11-27 03:32:42,577] Trial 23 finished with value: 0.6939220202441223 and parameters: {'C': 0.11210755127836314, 'l1_ratio': 0.3987388053426557}. Best is trial 10 with value: 0.6974642557281265.
# [I 2025-11-27 03:33:29,093] Trial 24 finished with value: 0.6576855835272382 and parameters: {'C': 7.171855169180249, 'l1_ratio': 0.19921250855367792}. Best is trial 10 with value: 0.6974642557281265.
# [I 2025-11-27 03:34:01,368] Trial 25 finished with value: 0.6676349484109732 and parameters: {'C': 2.0990889615392265, 'l1_ratio': 0.49366567255164345}. Best is trial 10 with value: 0.6974642557281265.
# [I 2025-11-27 03:34:43,082] Trial 26 finished with value: 0.6599793510430478 and parameters: {'C': 4.641822900371699, 'l1_ratio': 0.35653686980366794}. Best is trial 10 with value: 0.6974642557281265.
# [I 2025-11-27 03:35:01,686] Trial 27 finished with value: 0.6815816231811748 and parameters: {'C': 0.7167470138939538, 'l1_ratio': 0.17150234050817525}. Best is trial 10 with value: 0.6974642557281265.
# [I 2025-11-27 03:35:27,472] Trial 28 finished with value: 0.6722656772004066 and parameters: {'C': 1.4298117399611951, 'l1_ratio': 0.25357347349836573}. Best is trial 10 with value: 0.6974642557281265.
# [I 2025-11-27 03:36:07,731] Trial 29 finished with value: 0.6609916512714902 and parameters: {'C': 4.15252898098611, 'l1_ratio': 0.28157545810101337}. Best is trial 10 with value: 0.6974642557281265.
# Mejores parámetros:  {'C': 0.06530850310086017, 'l1_ratio': 0.14605252074281166}
# Mejor ROC_AUC= 0.6974642557281265

# %% [markdown]
# **Valores que se han obtenido**
#
# Checkpoint por si se vuelve a ejecutar y ya nos descuadra todo.
# Si eso sucediese, debería bastar con entrenar el modelo con los parámetros obtenido y que se muestran aquí abajo:
#
# **Mejores parámetros**: {'C': 0.06530850310086017, 'l1_ratio': 0.14605252074281166}
#
# **Mejor ROC_AUC**: 0.6974642557281265

# %%
# Mejor modelo de regresión logística
best_logreg_model = log_reg_results["best_model"]

# %% [markdown]
# **Random Forest**
#
# * Modelo basado en múltiples árboles de decisión entrenados sobre subconjuntos de datos y características.
# * Robusto frente a overfitting gracias al bagging.
# * Permite manejar datasets desbalanceados con class_weight="balanced".
# * Para reproducibilidad random_state.
# * Hiperparámetros clave:
#     * **n_estimators**: Número de árboles. A más árboles más estabilidad pero más coste de procesado.
#     * **max_depth**: Profundidad máxima de cada árbol. Controla el sobreajuste
#     * **max_features**: Número de features consideradas en cada nodo.
#     * **min_samples_split**: Mínimo de muestras para dividir un nodo.
#
# Se evalúan todas las combinaciones de hiperparámetros siguientes:
# * **n_estimators**: 100 a 500
# * **max_depth**: 5 a 20
# * **max_features**: "sqrt" y "log2"
# * **min_samples_split**: 2 a 10

# %%
# NOTA: Esta celda tarda alrededor de 15 minutos en el hardware original usado
# Modelo Random Forest para selección de genes

# Estimador
rf = RandomForestClassifier(class_weight="balanced", random_state=rng_seed)

# Rangos de hiperparámetros
rf_param_grid = {
    "n_estimators": ["I", 100, 500],
    "max_depth": ["I", 5, 20],
    "max_features": ["C", "sqrt", "log2"],
    "min_samples_split": ["I", 2, 10]
}

# Entrenamiento con validación cruzada
rf_results = train_with_cv(rf, rf_param_grid, X_train, y_train, scoring="roc_auc", n_splits=5)

print("Mejores parámetros: ", rf_results["best_params"], 
      "\nMejor ROC_AUC=", rf_results["best_score"])
# Out:
# [I 2025-11-27 03:36:08,586] A new study created in memory with name: no-name-1fb6699c-8c03-44e9-b6d0-7248795cc70e
# [I 2025-11-27 03:36:15,271] Trial 0 finished with value: 0.7223066500147237 and parameters: {'n_estimators': 184, 'max_depth': 9, 'max_features': 'log2', 'min_samples_split': 7}. Best is trial 0 with value: 0.7223066500147237.
# [I 2025-11-27 03:36:19,810] Trial 1 finished with value: 0.7300834085767773 and parameters: {'n_estimators': 118, 'max_depth': 11, 'max_features': 'log2', 'min_samples_split': 3}. Best is trial 1 with value: 0.7300834085767773.
# [I 2025-11-27 03:36:47,533] Trial 2 finished with value: 0.7331548570819437 and parameters: {'n_estimators': 337, 'max_depth': 19, 'max_features': 'sqrt', 'min_samples_split': 3}. Best is trial 2 with value: 0.7331548570819437.
# [I 2025-11-27 03:36:56,058] Trial 3 finished with value: 0.7224228594288207 and parameters: {'n_estimators': 159, 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_split': 3}. Best is trial 2 with value: 0.7331548570819437.
# [I 2025-11-27 03:37:07,009] Trial 4 finished with value: 0.727188229067907 and parameters: {'n_estimators': 133, 'max_depth': 17, 'max_features': 'sqrt', 'min_samples_split': 6}. Best is trial 2 with value: 0.7331548570819437.
# [I 2025-11-27 03:37:18,171] Trial 5 finished with value: 0.7255963293176692 and parameters: {'n_estimators': 319, 'max_depth': 8, 'max_features': 'log2', 'min_samples_split': 2}. Best is trial 2 with value: 0.7331548570819437.
# [I 2025-11-27 03:37:47,560] Trial 6 finished with value: 0.7325652051386952 and parameters: {'n_estimators': 360, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_split': 9}. Best is trial 2 with value: 0.7331548570819437.
# [I 2025-11-27 03:38:04,573] Trial 7 finished with value: 0.7327383891110119 and parameters: {'n_estimators': 399, 'max_depth': 20, 'max_features': 'log2', 'min_samples_split': 7}. Best is trial 2 with value: 0.7331548570819437.
# [I 2025-11-27 03:38:14,893] Trial 8 finished with value: 0.7291687083776281 and parameters: {'n_estimators': 250, 'max_depth': 15, 'max_features': 'log2', 'min_samples_split': 8}. Best is trial 2 with value: 0.7331548570819437.
# [I 2025-11-27 03:38:32,877] Trial 9 finished with value: 0.7286000681340294 and parameters: {'n_estimators': 264, 'max_depth': 9, 'max_features': 'sqrt', 'min_samples_split': 4}. Best is trial 2 with value: 0.7331548570819437.
# [I 2025-11-27 03:39:13,226] Trial 10 finished with value: 0.7365019643714807 and parameters: {'n_estimators': 495, 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_split': 4}. Best is trial 10 with value: 0.7365019643714807.
# [I 2025-11-27 03:39:53,632] Trial 11 finished with value: 0.7331971936034773 and parameters: {'n_estimators': 497, 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_split': 5}. Best is trial 10 with value: 0.7365019643714807.
# [I 2025-11-27 03:40:32,597] Trial 12 finished with value: 0.7347787808525924 and parameters: {'n_estimators': 491, 'max_depth': 14, 'max_features': 'sqrt', 'min_samples_split': 5}. Best is trial 10 with value: 0.7365019643714807.
# [I 2025-11-27 03:41:11,593] Trial 13 finished with value: 0.7329495224714824 and parameters: {'n_estimators': 495, 'max_depth': 13, 'max_features': 'sqrt', 'min_samples_split': 5}. Best is trial 10 with value: 0.7365019643714807.
# [I 2025-11-27 03:41:46,669] Trial 14 finished with value: 0.7320146198995511 and parameters: {'n_estimators': 438, 'max_depth': 13, 'max_features': 'sqrt', 'min_samples_split': 5}. Best is trial 10 with value: 0.7365019643714807.
# [I 2025-11-27 03:42:22,129] Trial 15 finished with value: 0.7319912332618627 and parameters: {'n_estimators': 437, 'max_depth': 16, 'max_features': 'sqrt', 'min_samples_split': 4}. Best is trial 10 with value: 0.7365019643714807.
# [I 2025-11-27 03:42:55,119] Trial 16 finished with value: 0.7318123224036563 and parameters: {'n_estimators': 443, 'max_depth': 11, 'max_features': 'sqrt', 'min_samples_split': 6}. Best is trial 10 with value: 0.7365019643714807.
# [I 2025-11-27 03:43:27,076] Trial 17 finished with value: 0.7290747682852692 and parameters: {'n_estimators': 393, 'max_depth': 18, 'max_features': 'sqrt', 'min_samples_split': 10}. Best is trial 10 with value: 0.7365019643714807.
# [I 2025-11-27 03:44:05,216] Trial 18 finished with value: 0.7340790536111463 and parameters: {'n_estimators': 469, 'max_depth': 14, 'max_features': 'sqrt', 'min_samples_split': 4}. Best is trial 10 with value: 0.7365019643714807.
# [I 2025-11-27 03:44:34,088] Trial 19 finished with value: 0.7303602839180249 and parameters: {'n_estimators': 391, 'max_depth': 11, 'max_features': 'sqrt', 'min_samples_split': 2}. Best is trial 10 with value: 0.7365019643714807.
# [I 2025-11-27 03:44:53,288] Trial 20 finished with value: 0.7294201729084931 and parameters: {'n_estimators': 238, 'max_depth': 17, 'max_features': 'sqrt', 'min_samples_split': 7}. Best is trial 10 with value: 0.7365019643714807.
# [I 2025-11-27 03:45:32,183] Trial 21 finished with value: 0.7342396134531685 and parameters: {'n_estimators': 479, 'max_depth': 14, 'max_features': 'sqrt', 'min_samples_split': 4}. Best is trial 10 with value: 0.7365019643714807.
# [I 2025-11-27 03:46:08,733] Trial 22 finished with value: 0.7323782968306384 and parameters: {'n_estimators': 470, 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_split': 5}. Best is trial 10 with value: 0.7365019643714807.
# [I 2025-11-27 03:46:44,069] Trial 23 finished with value: 0.7315198200385569 and parameters: {'n_estimators': 458, 'max_depth': 12, 'max_features': 'sqrt', 'min_samples_split': 4}. Best is trial 10 with value: 0.7365019643714807.
# [I 2025-11-27 03:47:17,147] Trial 24 finished with value: 0.7335909798895106 and parameters: {'n_estimators': 413, 'max_depth': 14, 'max_features': 'sqrt', 'min_samples_split': 3}. Best is trial 10 with value: 0.7365019643714807.
# [I 2025-11-27 03:47:57,581] Trial 25 finished with value: 0.732224233847213 and parameters: {'n_estimators': 499, 'max_depth': 17, 'max_features': 'sqrt', 'min_samples_split': 6}. Best is trial 10 with value: 0.7365019643714807.
# [I 2025-11-27 03:48:13,437] Trial 26 finished with value: 0.7323849990152904 and parameters: {'n_estimators': 363, 'max_depth': 12, 'max_features': 'log2', 'min_samples_split': 4}. Best is trial 10 with value: 0.7365019643714807.
# [I 2025-11-27 03:48:48,003] Trial 27 finished with value: 0.7345921925109717 and parameters: {'n_estimators': 427, 'max_depth': 14, 'max_features': 'sqrt', 'min_samples_split': 5}. Best is trial 10 with value: 0.7365019643714807.
# [I 2025-11-27 03:49:11,272] Trial 28 finished with value: 0.729975911831623 and parameters: {'n_estimators': 284, 'max_depth': 16, 'max_features': 'sqrt', 'min_samples_split': 5}. Best is trial 10 with value: 0.7365019643714807.
# [I 2025-11-27 03:49:26,813] Trial 29 finished with value: 0.7284582083624853 and parameters: {'n_estimators': 426, 'max_depth': 9, 'max_features': 'log2', 'min_samples_split': 8}. Best is trial 10 with value: 0.7365019643714807.
# Mejores parámetros:  {'n_estimators': 495, 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_split': 4}
# Mejor ROC_AUC= 0.7365019643714807

# %% [markdown]
# **Valores que se han obtenido**
#
# Checkpoint por si se vuelve a ejecutar y ya nos descuadra todo.
# Si eso sucediese, debería bastar con entrenar el modelo con los parámetros obtenido y que se muestran aquí abajo:
#
# **Mejores parámetros**: {'n_estimators': 495, 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_split': 4}
#
# **Mejor ROC_AUC**: 0.7365019643714807

# %%
# Mejor modelo de Random Forest
best_rf_model = rf_results["best_model"]

# %% [markdown]
# **XGBoost**
#
# * Algoritmo de boosting basado en gradiente, muy eficiente y potente.
# * Maneja correlaciones y complejidad del dataset mejor que Random Forest.
# * Permite ponderar clases desbalanceadas con scale_pos_weight.
# * No maneja variables categóricas automáticamente así que hay que codificarse con 0/1
# * Hiperparámetros clave:
#     * *De árbol*
#         * **n_estimators**: número de árboles.
#         * **max_depth**: profundidad máxima.
#         * **learning_rate**: tasa de aprendizaje.
#         * **min_child_weight**: Peso mínimo de un nodo para permitir la división (reduce sobreajuste)
#     * *De regularización*
#         * **reg_alpha**: Regularización L1
#         * **reg_lambda**: Regularización L2
#     * *De muestreo*
#         * **subsample**: fracción de muestras usadas en cada árbol.
#         * **colsample_bytree**: fracción de features usadas en cada árbol.
#
# XGBoost es mucho más pesado que los anteriores algoritmos, así que como sólo se necesita en este punto para selección de características se evaluará usando 5 iteraciones aleatorias del grid de parámetros.
#
# Se evaluan 5 combinaciones aleatorias de los hiperparámetros siguientes:
# * **n_estimators**: 200 a 1000
# * **max_depth**: 4 a 12
# * **learning_rate**: 0.05 a 0.3
# * **min_child_weight**: 1 a 5
# * **reg_alpha**: 0 a 1
# * **reg_lambda**: 1 a 10
# * **subsample**: 0.8 a 1.0
# * **colsample_bytree**: 0.8 a 1.0

# %%
# NOTA: Esta celda tarda alrededor de 6 minutos en el hardware original usado
# Modelo XGBoost para selección de genes

# Ratio de balanceo
balance_value = (y_train=="Non_response").sum() / (y_train=="Response").sum()

# Clases objetivo a binario: Non_response=0, Response=1
le = LabelEncoder()
y_train_encoded = le.fit_transform(y_train)

# Estimador
xgboost = XGBClassifier(scale_pos_weight=balance_value, eval_metric="auc", random_state=rng_seed)

# Rangos de hiperparámetros
xgboost_param_grid = {
    "n_estimators": ["I", 200, 1000],
    "max_depth": ["I", 4, 12],
    "learning_rate": ["F", 0.05, 0.3],
    "min_child_weight": ["I", 1, 5],
    "reg_alpha": ["I", 0, 1],
    "reg_lambda": ["I", 1, 10],
    "subsample": ["F", 0.8, 1.0],
    "colsample_bytree": ["F", 0.8, 1.0]
}

# Entrenamiento con validación cruzada
xgboost_results = train_with_cv(
    xgboost, xgboost_param_grid, X_train, y_train_encoded, scoring="roc_auc", n_splits=5)

print("Mejores parámetros: ", xgboost_results["best_params"], 
      "\nMejor ROC_AUC=", xgboost_results["best_score"])
# Out:
# [I 2025-11-27 03:49:36,700] A new study created in memory with name: no-name-41efd143-f8d4-4084-b69f-75b6179cbba1
# [I 2025-11-27 03:49:43,316] Trial 0 finished with value: 0.7247221467934145 and parameters: {'n_estimators': 322, 'max_depth': 8, 'learning_rate': 0.2820590292016061, 'min_child_weight': 4, 'reg_alpha': 1, 'reg_lambda': 3, 'subsample': 0.8333459710842, 'colsample_bytree': 0.8385188354014745}. Best is trial 0 with value: 0.7247221467934145.
# [I 2025-11-27 03:49:49,277] Trial 1 finished with value: 0.7210556214595158 and parameters: {'n_estimators': 909, 'max_depth': 7, 'learning_rate': 0.2773950503020651, 'min_child_weight': 5, 'reg_alpha': 1, 'reg_lambda': 2, 'subsample': 0.9517549820640878, 'colsample_bytree': 0.94105125034951}. Best is trial 0 with value: 0.7247221467934145.
# [I 2025-11-27 03:50:03,725] Trial 2 finished with value: 0.7240676528819308 and parameters: {'n_estimators': 261, 'max_depth': 10, 'learning_rate': 0.13769398669155386, 'min_child_weight': 2, 'reg_alpha': 1, 'reg_lambda': 9, 'subsample': 0.9569838915332765, 'colsample_bytree': 0.8644163318043383}. Best is trial 0 with value: 0.7247221467934145.
# [I 2025-11-27 03:50:18,917] Trial 3 finished with value: 0.7290362936046237 and parameters: {'n_estimators': 406, 'max_depth': 8, 'learning_rate': 0.2882062124460524, 'min_child_weight': 1, 'reg_alpha': 1, 'reg_lambda': 10, 'subsample': 0.9090202725451889, 'colsample_bytree': 0.9178512752692959}. Best is trial 3 with value: 0.7290362936046237.
# [I 2025-11-27 03:50:27,287] Trial 4 finished with value: 0.7247512894048505 and parameters: {'n_estimators': 829, 'max_depth': 11, 'learning_rate': 0.16408748391931366, 'min_child_weight': 5, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 0.8226264446503273, 'colsample_bytree': 0.8300371806114971}. Best is trial 3 with value: 0.7290362936046237.
# [I 2025-11-27 03:50:34,861] Trial 5 finished with value: 0.731164133713118 and parameters: {'n_estimators': 482, 'max_depth': 4, 'learning_rate': 0.10876422537109255, 'min_child_weight': 4, 'reg_alpha': 1, 'reg_lambda': 4, 'subsample': 0.9938794268973059, 'colsample_bytree': 0.8075891582987206}. Best is trial 5 with value: 0.731164133713118.
# [I 2025-11-27 03:51:18,876] Trial 6 finished with value: 0.7342842385046925 and parameters: {'n_estimators': 978, 'max_depth': 7, 'learning_rate': 0.13737867328433417, 'min_child_weight': 2, 'reg_alpha': 0, 'reg_lambda': 10, 'subsample': 0.9433783632511783, 'colsample_bytree': 0.9474874406636857}. Best is trial 6 with value: 0.7342842385046925.
# [I 2025-11-27 03:51:40,181] Trial 7 finished with value: 0.7257432760422308 and parameters: {'n_estimators': 951, 'max_depth': 12, 'learning_rate': 0.11685638806100375, 'min_child_weight': 2, 'reg_alpha': 1, 'reg_lambda': 6, 'subsample': 0.8728380168320081, 'colsample_bytree': 0.9991922542112202}. Best is trial 6 with value: 0.7342842385046925.
# [I 2025-11-27 03:51:56,739] Trial 8 finished with value: 0.7342335854223976 and parameters: {'n_estimators': 871, 'max_depth': 10, 'learning_rate': 0.15859013699126212, 'min_child_weight': 2, 'reg_alpha': 1, 'reg_lambda': 3, 'subsample': 0.9744438107882762, 'colsample_bytree': 0.9903326981427956}. Best is trial 6 with value: 0.7342842385046925.
# [I 2025-11-27 03:52:05,828] Trial 9 finished with value: 0.7288195976191075 and parameters: {'n_estimators': 914, 'max_depth': 8, 'learning_rate': 0.22252333124725449, 'min_child_weight': 4, 'reg_alpha': 0, 'reg_lambda': 6, 'subsample': 0.9707093484566756, 'colsample_bytree': 0.9841232329278418}. Best is trial 6 with value: 0.7342842385046925.
# [I 2025-11-27 03:52:13,467] Trial 10 finished with value: 0.7263025850721456 and parameters: {'n_estimators': 674, 'max_depth': 5, 'learning_rate': 0.06861633639740902, 'min_child_weight': 1, 'reg_alpha': 0, 'reg_lambda': 8, 'subsample': 0.9133685124215839, 'colsample_bytree': 0.9422927335845994}. Best is trial 6 with value: 0.7342842385046925.
# [I 2025-11-27 03:52:25,063] Trial 11 finished with value: 0.7264628805568716 and parameters: {'n_estimators': 727, 'max_depth': 10, 'learning_rate': 0.19060423915642905, 'min_child_weight': 2, 'reg_alpha': 0, 'reg_lambda': 4, 'subsample': 0.9324946970549048, 'colsample_bytree': 0.9650910802410168}. Best is trial 6 with value: 0.7342842385046925.
# [I 2025-11-27 03:52:32,782] Trial 12 finished with value: 0.7274688396323089 and parameters: {'n_estimators': 993, 'max_depth': 6, 'learning_rate': 0.21010760037752557, 'min_child_weight': 3, 'reg_alpha': 0, 'reg_lambda': 7, 'subsample': 0.985498291401163, 'colsample_bytree': 0.8910213281476026}. Best is trial 6 with value: 0.7342842385046925.
# [I 2025-11-27 03:52:44,581] Trial 13 finished with value: 0.7327683718482236 and parameters: {'n_estimators': 771, 'max_depth': 9, 'learning_rate': 0.07882815472069134, 'min_child_weight': 3, 'reg_alpha': 0, 'reg_lambda': 4, 'subsample': 0.874351961943307, 'colsample_bytree': 0.9600261567167765}. Best is trial 6 with value: 0.7342842385046925.
# [I 2025-11-27 03:53:03,827] Trial 14 finished with value: 0.7311844130831708 and parameters: {'n_estimators': 576, 'max_depth': 6, 'learning_rate': 0.15359296507962555, 'min_child_weight': 2, 'reg_alpha': 0, 'reg_lambda': 10, 'subsample': 0.9419854540655541, 'colsample_bytree': 0.9058858381258224}. Best is trial 6 with value: 0.7342842385046925.
# [I 2025-11-27 03:53:25,909] Trial 15 finished with value: 0.727006873118593 and parameters: {'n_estimators': 858, 'max_depth': 10, 'learning_rate': 0.23294465451385388, 'min_child_weight': 1, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 0.9748911409344037, 'colsample_bytree': 0.9740691044815536}. Best is trial 6 with value: 0.7342842385046925.
# [I 2025-11-27 03:53:41,420] Trial 16 finished with value: 0.7303541412468733 and parameters: {'n_estimators': 581, 'max_depth': 12, 'learning_rate': 0.1058058330294326, 'min_child_weight': 3, 'reg_alpha': 1, 'reg_lambda': 5, 'subsample': 0.8839611552732903, 'colsample_bytree': 0.9997232600975009}. Best is trial 6 with value: 0.7342842385046925.
# [I 2025-11-27 03:53:59,323] Trial 17 finished with value: 0.7285092515642851 and parameters: {'n_estimators': 805, 'max_depth': 9, 'learning_rate': 0.19315625846699572, 'min_child_weight': 2, 'reg_alpha': 0, 'reg_lambda': 8, 'subsample': 0.9998212180905114, 'colsample_bytree': 0.927302906445292}. Best is trial 6 with value: 0.7342842385046925.
# [I 2025-11-27 03:54:13,949] Trial 18 finished with value: 0.7354481643251796 and parameters: {'n_estimators': 663, 'max_depth': 7, 'learning_rate': 0.13659805871785574, 'min_child_weight': 1, 'reg_alpha': 1, 'reg_lambda': 3, 'subsample': 0.9265648375245761, 'colsample_bytree': 0.9486714709420677}. Best is trial 18 with value: 0.7354481643251796.
# [I 2025-11-27 03:54:23,791] Trial 19 finished with value: 0.7276076229351258 and parameters: {'n_estimators': 640, 'max_depth': 6, 'learning_rate': 0.053949759312537066, 'min_child_weight': 1, 'reg_alpha': 0, 'reg_lambda': 7, 'subsample': 0.9221481541856057, 'colsample_bytree': 0.8835958997495462}. Best is trial 18 with value: 0.7354481643251796.
# [I 2025-11-27 03:54:40,638] Trial 20 finished with value: 0.7304746573749782 and parameters: {'n_estimators': 518, 'max_depth': 7, 'learning_rate': 0.13266218133217575, 'min_child_weight': 1, 'reg_alpha': 1, 'reg_lambda': 5, 'subsample': 0.8463071481128032, 'colsample_bytree': 0.949542957029765}. Best is trial 18 with value: 0.7354481643251796.
# [I 2025-11-27 03:54:51,814] Trial 21 finished with value: 0.7351807938692377 and parameters: {'n_estimators': 877, 'max_depth': 7, 'learning_rate': 0.17093190932261196, 'min_child_weight': 2, 'reg_alpha': 1, 'reg_lambda': 3, 'subsample': 0.9588605972737224, 'colsample_bytree': 0.9802961021039868}. Best is trial 18 with value: 0.7354481643251796.
# [I 2025-11-27 03:55:01,168] Trial 22 finished with value: 0.7274270318253675 and parameters: {'n_estimators': 723, 'max_depth': 7, 'learning_rate': 0.17523103642353574, 'min_child_weight': 3, 'reg_alpha': 1, 'reg_lambda': 3, 'subsample': 0.9360334399506887, 'colsample_bytree': 0.933835264710196}. Best is trial 18 with value: 0.7354481643251796.
# [I 2025-11-27 03:55:07,216] Trial 23 finished with value: 0.726134358868537 and parameters: {'n_estimators': 968, 'max_depth': 5, 'learning_rate': 0.13509020010530035, 'min_child_weight': 2, 'reg_alpha': 1, 'reg_lambda': 2, 'subsample': 0.9038175560675105, 'colsample_bytree': 0.9713111894649288}. Best is trial 18 with value: 0.7354481643251796.
# [I 2025-11-27 03:55:20,823] Trial 24 finished with value: 0.7335835795962706 and parameters: {'n_estimators': 997, 'max_depth': 7, 'learning_rate': 0.08911032699737485, 'min_child_weight': 1, 'reg_alpha': 1, 'reg_lambda': 2, 'subsample': 0.954900162116482, 'colsample_bytree': 0.9548452411170695}. Best is trial 18 with value: 0.7354481643251796.
# [I 2025-11-27 03:55:28,459] Trial 25 finished with value: 0.7369736102976493 and parameters: {'n_estimators': 769, 'max_depth': 5, 'learning_rate': 0.24537327663037428, 'min_child_weight': 1, 'reg_alpha': 1, 'reg_lambda': 5, 'subsample': 0.931874387397527, 'colsample_bytree': 0.9151191754856337}. Best is trial 25 with value: 0.7369736102976493.
# [I 2025-11-27 03:55:33,966] Trial 26 finished with value: 0.7258806528615693 and parameters: {'n_estimators': 749, 'max_depth': 4, 'learning_rate': 0.2334097696479385, 'min_child_weight': 1, 'reg_alpha': 1, 'reg_lambda': 5, 'subsample': 0.8895818214932688, 'colsample_bytree': 0.9202048061432084}. Best is trial 25 with value: 0.7369736102976493.
# [I 2025-11-27 03:55:41,411] Trial 27 finished with value: 0.7242301684546288 and parameters: {'n_estimators': 650, 'max_depth': 5, 'learning_rate': 0.26135309649900407, 'min_child_weight': 1, 'reg_alpha': 1, 'reg_lambda': 4, 'subsample': 0.920129288135154, 'colsample_bytree': 0.9005057896638583}. Best is trial 25 with value: 0.7369736102976493.
# [I 2025-11-27 03:55:48,790] Trial 28 finished with value: 0.7331466029745243 and parameters: {'n_estimators': 787, 'max_depth': 6, 'learning_rate': 0.25271783105647144, 'min_child_weight': 1, 'reg_alpha': 1, 'reg_lambda': 3, 'subsample': 0.8017400800193587, 'colsample_bytree': 0.8749116735656053}. Best is trial 25 with value: 0.7369736102976493.
# [I 2025-11-27 03:56:01,454] Trial 29 finished with value: 0.7267112720411104 and parameters: {'n_estimators': 704, 'max_depth': 8, 'learning_rate': 0.18820456647650471, 'min_child_weight': 1, 'reg_alpha': 1, 'reg_lambda': 3, 'subsample': 0.9251088028005219, 'colsample_bytree': 0.8591786037767171}. Best is trial 25 with value: 0.7369736102976493.
# Mejores parámetros:  {'n_estimators': 769, 'max_depth': 5, 'learning_rate': 0.24537327663037428, 'min_child_weight': 1, 'reg_alpha': 1, 'reg_lambda': 5, 'subsample': 0.931874387397527, 'colsample_bytree': 0.9151191754856337}
# Mejor ROC_AUC= 0.7369736102976493

# %% [markdown]
# **Valores que se han obtenido**
#
# Checkpoint por si se vuelve a ejecutar y ya nos descuadra todo.
# Si eso sucediese, debería bastar con entrenar el modelo con los parámetros obtenido y que se muestran aquí abajo:
#
# **Mejores parámetros**: {'n_estimators': 769, 'max_depth': 5, 'learning_rate': 0.24537327663037428, 'min_child_weight': 1, 'reg_alpha': 1, 'reg_lambda': 5, 'subsample': 0.931874387397527, 'colsample_bytree': 0.9151191754856337}
#
# **Mejor ROC_AUC**: 0.7369736102976493

# %%
# Mejor modelo de XGBoost
best_xgboost_model = xgboost_results["best_model"]

# %% [markdown]
# **CatBoost**
#
# * Algoritmo de boosting que maneja automáticamente variables categóricas.
# * Muy eficiente en datasets con alta cardinalidad y correlaciones.
# * Permite ponderar clases desbalanceadas con class_weights y pasándole una lista de pesos por clase.
# * Hiperparámetros clave:
#     * **iterations**: número de árboles.
#     * **depth**: profundidad máxima.
#     * **learning_rate**: tasa de aprendizaje.
#     * **l2_leaf_reg**: regularización L2 en hojas.
#     * **rsm**: Fracción de las características a usar en cada iteración de boosting.
#
# CatBoost, también es más pesado que los Regresión Logística y que Random Forest, así que como sólo se necesita en este punto para selección de características se evaluará usando 5 iteraciones aleatorias del grid de parámetros.
#
# Se evaluan 5 combinaciones aleatorias de los hiperparámetros siguientes:
# * **iterations**: 200 a 1000
# * **depth**: 4 a 8
# * **learning_rate**: 0.01 a 0.3
# * **l2_leaf_reg**: 1 a 5
# * **rsm**: 0.8 a 1.0

# %%
# NOTA: Esta celda tarda alrededor de 10 minutos en el hardware original usado
# Modelo CatBoost para selección de genes

# Ratio de balanceo
balance_value = (y_train=="Non_response").sum() / (y_train=="Response").sum()

# Estimador
catboost = CatBoostClassifier(class_weights=[1, balance_value], eval_metric="AUC", 
                              early_stopping_rounds=50, random_state=rng_seed)

# Rangos de hiperparámetros
catboost_param_grid = {
    "iterations": ["I", 200, 1000],
    "depth": ["I", 4, 8],
    "learning_rate": ["F", 0.01, 0.3],
    "l2_leaf_reg": ["I", 1, 5],
    "rsm": ["F", 0.8, 1.0]
}

# Entrenamiento con validación cruzada
catboost_results = train_with_cv(
    catboost, catboost_param_grid, X_train, y_train_encoded, scoring="roc_auc", n_splits=5)

print("Mejores parámetros: ", catboost_results["best_params"], 
      "\nMejor ROC_AUC=", catboost_results["best_score"])
# Out:
# [I 2025-11-27 03:56:05,750] A new study created in memory with name: no-name-365a4bcb-d5fb-49d4-8347-bbead89e8e68
# [I 2025-11-27 03:56:43,267] Trial 0 finished with value: 0.736646450605481 and parameters: {'iterations': 828, 'depth': 8, 'learning_rate': 0.13283762592251164, 'l2_leaf_reg': 2, 'rsm': 0.8477973897539226}. Best is trial 0 with value: 0.736646450605481.
# [I 2025-11-27 03:57:43,958] Trial 1 finished with value: 0.7248961914241123 and parameters: {'iterations': 797, 'depth': 8, 'learning_rate': 0.015528165986080245, 'l2_leaf_reg': 5, 'rsm': 0.9273285322045158}. Best is trial 0 with value: 0.736646450605481.
# [I 2025-11-27 03:57:57,213] Trial 2 finished with value: 0.7164337293901833 and parameters: {'iterations': 646, 'depth': 7, 'learning_rate': 0.07033013486350302, 'l2_leaf_reg': 2, 'rsm': 0.9414652969303355}. Best is trial 0 with value: 0.736646450605481.
# [I 2025-11-27 03:58:02,001] Trial 3 finished with value: 0.7237232252685193 and parameters: {'iterations': 834, 'depth': 4, 'learning_rate': 0.051393317779228155, 'l2_leaf_reg': 1, 'rsm': 0.9477734181867852}. Best is trial 0 with value: 0.736646450605481.
# [I 2025-11-27 03:58:18,167] Trial 4 finished with value: 0.7303612575057368 and parameters: {'iterations': 526, 'depth': 7, 'learning_rate': 0.25272010249211413, 'l2_leaf_reg': 2, 'rsm': 0.9838009492588882}. Best is trial 0 with value: 0.736646450605481.
# [I 2025-11-27 03:58:30,088] Trial 5 finished with value: 0.7122646018051924 and parameters: {'iterations': 848, 'depth': 7, 'learning_rate': 0.28191951870106247, 'l2_leaf_reg': 4, 'rsm': 0.9949297863791189}. Best is trial 0 with value: 0.736646450605481.
# [I 2025-11-27 03:59:19,780] Trial 6 finished with value: 0.7231645724264562 and parameters: {'iterations': 983, 'depth': 8, 'learning_rate': 0.09478849768671235, 'l2_leaf_reg': 3, 'rsm': 0.8585861449003973}. Best is trial 0 with value: 0.736646450605481.
# [I 2025-11-27 03:59:22,769] Trial 7 finished with value: 0.6960036517238919 and parameters: {'iterations': 223, 'depth': 4, 'learning_rate': 0.013106717461322574, 'l2_leaf_reg': 4, 'rsm': 0.9074926563269562}. Best is trial 0 with value: 0.736646450605481.
# [I 2025-11-27 03:59:47,771] Trial 8 finished with value: 0.7188708521356391 and parameters: {'iterations': 580, 'depth': 7, 'learning_rate': 0.2066691546490179, 'l2_leaf_reg': 3, 'rsm': 0.8823578543792993}. Best is trial 0 with value: 0.736646450605481.
# [I 2025-11-27 03:59:50,762] Trial 9 finished with value: 0.7088536389680107 and parameters: {'iterations': 502, 'depth': 4, 'learning_rate': 0.13254294413499354, 'l2_leaf_reg': 4, 'rsm': 0.9376238740307838}. Best is trial 0 with value: 0.736646450605481.
# [I 2025-11-27 03:59:57,880] Trial 10 finished with value: 0.7087107405888374 and parameters: {'iterations': 332, 'depth': 5, 'learning_rate': 0.20024135107622032, 'l2_leaf_reg': 1, 'rsm': 0.8017539428228029}. Best is trial 0 with value: 0.736646450605481.
# [I 2025-11-27 04:00:02,141] Trial 11 finished with value: 0.7014331929758642 and parameters: {'iterations': 425, 'depth': 6, 'learning_rate': 0.29203338846041976, 'l2_leaf_reg': 2, 'rsm': 0.8319362722136251}. Best is trial 0 with value: 0.736646450605481.
# [I 2025-11-27 04:00:33,679] Trial 12 finished with value: 0.7302688316930348 and parameters: {'iterations': 688, 'depth': 8, 'learning_rate': 0.1820562845041671, 'l2_leaf_reg': 2, 'rsm': 0.9983628705087624}. Best is trial 0 with value: 0.736646450605481.
# [I 2025-11-27 04:00:40,666] Trial 13 finished with value: 0.7154035461178575 and parameters: {'iterations': 977, 'depth': 6, 'learning_rate': 0.23327956234155478, 'l2_leaf_reg': 2, 'rsm': 0.8491728460690436}. Best is trial 0 with value: 0.736646450605481.
# [I 2025-11-27 04:00:51,304] Trial 14 finished with value: 0.7267772741015573 and parameters: {'iterations': 742, 'depth': 7, 'learning_rate': 0.13151567658614968, 'l2_leaf_reg': 1, 'rsm': 0.9757904702064789}. Best is trial 0 with value: 0.736646450605481.
# [I 2025-11-27 04:01:43,420] Trial 15 finished with value: 0.7229811957265488 and parameters: {'iterations': 542, 'depth': 8, 'learning_rate': 0.2487111029104124, 'l2_leaf_reg': 3, 'rsm': 0.8848470710295583}. Best is trial 0 with value: 0.736646450605481.
# [I 2025-11-27 04:01:53,482] Trial 16 finished with value: 0.7144537343077423 and parameters: {'iterations': 444, 'depth': 7, 'learning_rate': 0.15943700866350596, 'l2_leaf_reg': 2, 'rsm': 0.8066284414606264}. Best is trial 0 with value: 0.736646450605481.
# [I 2025-11-27 04:01:59,184] Trial 17 finished with value: 0.7117901831217532 and parameters: {'iterations': 899, 'depth': 6, 'learning_rate': 0.11102528393089417, 'l2_leaf_reg': 1, 'rsm': 0.9669294082640475}. Best is trial 0 with value: 0.736646450605481.
# [I 2025-11-27 04:02:05,022] Trial 18 finished with value: 0.7056169046994514 and parameters: {'iterations': 712, 'depth': 5, 'learning_rate': 0.24474598471448394, 'l2_leaf_reg': 2, 'rsm': 0.9077567648683953}. Best is trial 0 with value: 0.736646450605481.
# [I 2025-11-27 04:02:50,389] Trial 19 finished with value: 0.7182261864979982 and parameters: {'iterations': 328, 'depth': 8, 'learning_rate': 0.1561705729113335, 'l2_leaf_reg': 3, 'rsm': 0.8317832032010561}. Best is trial 0 with value: 0.736646450605481.
# [I 2025-11-27 04:03:02,469] Trial 20 finished with value: 0.7245734103100715 and parameters: {'iterations': 623, 'depth': 7, 'learning_rate': 0.17801770070212947, 'l2_leaf_reg': 3, 'rsm': 0.8606865531091485}. Best is trial 0 with value: 0.736646450605481.
# [I 2025-11-27 04:03:33,413] Trial 21 finished with value: 0.7255873907900656 and parameters: {'iterations': 684, 'depth': 8, 'learning_rate': 0.1985785590796929, 'l2_leaf_reg': 2, 'rsm': 0.9981905239983071}. Best is trial 0 with value: 0.736646450605481.
# [I 2025-11-27 04:04:17,294] Trial 22 finished with value: 0.7321177158229221 and parameters: {'iterations': 770, 'depth': 8, 'learning_rate': 0.22240908684217497, 'l2_leaf_reg': 2, 'rsm': 0.9757048698912539}. Best is trial 0 with value: 0.736646450605481.
# [I 2025-11-27 04:04:46,503] Trial 23 finished with value: 0.718201747564277 and parameters: {'iterations': 894, 'depth': 8, 'learning_rate': 0.2591939315161729, 'l2_leaf_reg': 1, 'rsm': 0.9772798026556149}. Best is trial 0 with value: 0.736646450605481.
# [I 2025-11-27 04:04:54,532] Trial 24 finished with value: 0.7211621985150478 and parameters: {'iterations': 748, 'depth': 7, 'learning_rate': 0.22942765612877142, 'l2_leaf_reg': 2, 'rsm': 0.9599638854312507}. Best is trial 0 with value: 0.736646450605481.
# [I 2025-11-27 04:05:30,721] Trial 25 finished with value: 0.7201433826064535 and parameters: {'iterations': 784, 'depth': 8, 'learning_rate': 0.27144143556228656, 'l2_leaf_reg': 2, 'rsm': 0.9222979105938595}. Best is trial 0 with value: 0.736646450605481.
# [I 2025-11-27 04:05:50,201] Trial 26 finished with value: 0.7209011007700925 and parameters: {'iterations': 877, 'depth': 7, 'learning_rate': 0.2274600128642645, 'l2_leaf_reg': 1, 'rsm': 0.8805795747294224}. Best is trial 0 with value: 0.736646450605481.
# [I 2025-11-27 04:06:35,838] Trial 27 finished with value: 0.7208917515903787 and parameters: {'iterations': 510, 'depth': 8, 'learning_rate': 0.2980629065260131, 'l2_leaf_reg': 3, 'rsm': 0.9571277435027338}. Best is trial 0 with value: 0.736646450605481.
# [I 2025-11-27 04:06:48,741] Trial 28 finished with value: 0.710063533014633 and parameters: {'iterations': 936, 'depth': 7, 'learning_rate': 0.21499477887869056, 'l2_leaf_reg': 2, 'rsm': 0.9822586605307493}. Best is trial 0 with value: 0.736646450605481.
# [I 2025-11-27 04:07:17,933] Trial 29 finished with value: 0.7236354175810092 and parameters: {'iterations': 807, 'depth': 8, 'learning_rate': 0.17498026321402832, 'l2_leaf_reg': 5, 'rsm': 0.9223765369338891}. Best is trial 0 with value: 0.736646450605481.
# Mejores parámetros:  {'iterations': 828, 'depth': 8, 'learning_rate': 0.13283762592251164, 'l2_leaf_reg': 2, 'rsm': 0.8477973897539226}
# Mejor ROC_AUC= 0.736646450605481

# %% [markdown]
# **Valores que se han obtenido**
#
# Checkpoint por si se vuelve a ejecutar y ya nos descuadra todo.
# Si eso sucediese, debería bastar con entrenar el modelo con los parámetros obtenido y que se muestran aquí abajo:
#
# **Mejores parámetros**: {'iterations': 828, 'depth': 8, 'learning_rate': 0.13283762592251164, 'l2_leaf_reg': 2, 'rsm': 0.8477973897539226}
#
# **Mejor ROC_AUC**: 0.736646450605481

# %%
# Mejor modelo de CatBoost
best_catboost_model = catboost_results["best_model"]

# %% [markdown]
# Una vez tenemos los modelos entrenados tenemos que hacer los siguientes pasos:
#
# 1. Obtener las importancias de cada modelo
# 2. Normalizarlas (para poder compararlas)
# 3. Combinar los rankings de cada modelo
# 4. Seleccionar las mejores features según el ranking global

# %% [markdown]
# #### 1.1 Obtener importancias de cada modelo

# %%
# Obtener importancias de features según cada modelo
logreg_importances = np.abs(best_logreg_model.coef_[0])
rf_importances = best_rf_model.feature_importances_
xgb_importances = best_xgboost_model.feature_importances_
cat_importances = best_catboost_model.feature_importances_

# %% [markdown]
# #### 1.2 Normalizar importancias de cada modelo

# %%
# Normalizar importancias de cada modelo
scaler = MinMaxScaler()
all_importances = np.vstack([
    logreg_importances,
    rf_importances,
    xgb_importances,
    cat_importances
])
normalized = scaler.fit_transform(all_importances.T).T

# %% [markdown]
# #### 1.3 Combinar rankings
#
# Se pueden usar diferentes métodos como promedio entre rankings, voto mayoritario o intersección.
#
# En este caso se opta por promedio entre rankings, debido a su sencillez, flexibilidad (no descarta características importantes detectadas por sólo un modelo) y suavidad que aporta (un modelo tiene más dificil dominar los demás por completo).

# %%
# Combinar rankings: Promedio de importancias
feature_names = X_train_scaled.columns
mean_importances = normalized.mean(axis=0)

importance_df = pd.DataFrame({
    "feature": feature_names,
    "LogisticRegression": normalized[0],
    "RandomForest": normalized[1],
    "XGBoost": normalized[2],
    "CatBoost": normalized[3],
    "mean_importance": mean_importances
}).sort_values("mean_importance", ascending=False)

importance_df
# Out:
#         feature  LogisticRegression  RandomForest   XGBoost  CatBoost  \
# 42        CHEK1            0.023895      1.000000  1.000000  0.729370
# 115       IKZF3            1.000000      0.443565  0.249987  0.714099
# 13         ASPM            0.290325      0.898818  0.536521  0.655007
# 24       CAMK1D            0.644618      0.324360  0.100617  1.000000
# 80       FNDC3B            0.541636      0.374104  0.162895  0.922510
# ..          ...                 ...           ...       ...       ...
# 275    TBC1D22B            0.000000      0.031393  0.008529  0.115445
# 101       HDAC4            0.000000      0.076492  0.018145  0.048237
# 82   GADD45GIP1            0.000000      0.010084  0.075334  0.057097
# 208     PLEKHA2            0.000000      0.030665  0.025846  0.017520
# 297        TPM3            0.000000      0.020208  0.024944  0.000000
#
#      mean_importance
# 42          0.688316
# 115         0.601913
# 13          0.595168
# 24          0.517399
# 80          0.500286
# ..               ...
# 275         0.038842
# 101         0.035719
# 82          0.035629
# 208         0.018508
# 297         0.011288
#
# [323 rows x 6 columns]

# %%
# Gráfico de top n más/menos importantes según el ranking global
# Seleccionamos top-n más importantes y top-n menos importantes
n = 20
mean_val = importance_df["mean_importance"].mean()

# Centrar en 0
importance_df["centered"] = importance_df["mean_importance"] - mean_val

# Seleccionar top/bottom n
top_features = importance_df.nlargest(n, "centered")
bottom_features = importance_df.nsmallest(n, "centered")
plot_df = pd.concat([top_features, bottom_features]).sort_values("centered")

# %%
# Gráfico
plt.figure(figsize=(6,6))
colors = plot_df["centered"].apply(lambda x: "tab:blue" if x > 0 else "tab:red")
plt.barh(plot_df["feature"], plot_df["centered"], color=colors)
plt.axvline(0, color="black", linewidth=0.8)
plt.xlabel("Importancia relativa (centrada en la media)")
plt.yticks(fontsize=8)
plt.title(f"Top {n} y Bottom {n} features")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6,6))
colors = plot_df["centered"].apply(lambda x: "tab:blue" if x > 0 else "tab:red")
plt.hlines(y=plot_df["feature"], xmin=0, xmax=plot_df["centered"], color=colors)
plt.plot(plot_df["centered"], plot_df["feature"], "o", color="black")
plt.axvline(0, color="black", linewidth=0.8)
plt.xlabel("Importancia relativa (centrada)")
plt.title("Lollipop divergente de importancias")
plt.tight_layout()
plt.show()

# %%
# Seleccionamos las top-N por importancia media
top_n = 20
top_features = importance_df.nlargest(top_n, "mean_importance")

# Construimos matriz para el heatmap
heatmap_data = top_features.set_index("feature")[["LogisticRegression", "RandomForest", "XGBoost", "CatBoost", "mean_importance"]]

# Dibujamos heatmap
plt.figure(figsize=(7, 8))
sns.heatmap(
    heatmap_data,
    cmap="YlGnBu",        # paleta de colores
    annot=True,           # muestra valores numéricos
    fmt=".2f",            # formato de los números
    cbar_kws={"label": "Importancia normalizada"}
)
plt.title(f"Heatmap de importancias (Top {top_n} features)")
plt.ylabel("Features")
plt.xlabel("Modelos")
plt.xticks(rotation=30, fontsize=8)
plt.tight_layout()
plt.show()

# %%
# Seleccionamos las top-N por importancia media
bottom_n = 20
bottom_features = importance_df.nsmallest(bottom_n, "mean_importance")

# Construimos matriz para el heatmap
heatmap_data = bottom_features.set_index("feature")[["LogisticRegression", "RandomForest", "XGBoost", "CatBoost", "mean_importance"]]
heatmap_data = heatmap_data.sort_values("mean_importance", ascending=False)

# Dibujamos heatmap
plt.figure(figsize=(7, 8))
sns.heatmap(
    heatmap_data,
    cmap="gist_heat",        # paleta de colores
    annot=True,           # muestra valores numéricos
    fmt=".2f",            # formato de los números
    cbar_kws={"label": "Importancia normalizada"}
)
plt.title(f"Heatmap de importancias (Top {top_n} features)")
plt.ylabel("Features")
plt.xlabel("Modelos")
plt.xticks(rotation=30, fontsize=8)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 1.4 Seleccionar las mejores features según importancia global

# %% [markdown]
# Llegados a este punto hay que decidir dónde cortar. Se comentó durante la fase de exploración que como referencia, para priorizar la explicabilidad operativa, el objetivo para el dataset final sería tener alrededor de unas 20 características. Esa es la referencia, el número concreto lo decidiremos en base a criterio técnico.
#
# Se probarán los siguientes métodos para seleccionar las características finales:
# * **Usar detección de codo**: Ordenar las importancias de mayor a menor y detectar el codo.
# * **Clusterizar con k-means**: Crear clústers basados en 3 niveles de importancia (alta, media, baja) y seleccionar las características del clúster de mayor importancia media.

# %% [markdown]
# **Detección de codo**

# %%
# Ordenar las importancias de mayor a menor
importances_sorted = np.sort(importance_df["mean_importance"].values)[::-1]

# Índices de las features
x = range(1, len(importances_sorted) + 1)

# Detectar el "codo" con KneeLocator
# La curva es convexa
knee = KneeLocator(
    x,
    importances_sorted,
    curve="convex",
    direction="decreasing"
)

elbow_point = knee.knee

# Dibujar el gráfico
plt.figure(figsize=(8,6))
plt.plot(x, importances_sorted, marker="o")
plt.axvline(elbow_point, color="red", linestyle="--", label=f"Codo en {elbow_point}")
plt.xlabel("Features ordenadas por importancia")
plt.ylabel("Importancia media")
plt.title("Curva de importancias y punto de corte (codo)")
plt.legend()
plt.tight_layout()
plt.show()

print(f"El punto de corte sugerido por KneeLocator es: {elbow_point} features")

# Seleccionar las características según el KneeLocator
elbow_selected_features = importance_df.nlargest(elbow_point, "mean_importance")["feature"].tolist()
print(f"\n{len(elbow_selected_features)} features seleccionadas:", elbow_selected_features)
# Out:
# El punto de corte sugerido por KneeLocator es: 24 features
#
# 24 features seleccionadas: ['CHEK1', 'IKZF3', 'ASPM', 'CAMK1D', 'FNDC3B', 'EHF', 'RSU1', 'EML4', 'GTF2A1', 'CCND2', 'RNF19A', 'CDT1', 'MAD2L1', 'UBE2S', 'EEA1', 'CRIPT', 'KLHL7', 'RAB28', 'CCNK', 'LUM', 'PLXDC2', 'CDK6', 'ACADSB', 'DTWD1']

# %% [markdown]
# **Elección de clúster con mayor importancia media K-means**

# %%
# Extraemos las importancias como array
X = importance_df[["mean_importance"]].values

# Definir número de clusters (alto, medio, bajo)
kmeans = KMeans(n_clusters=3, random_state=rng_seed)
importance_df["cluster"] = kmeans.fit_predict(X)

# Ordenar los clusters por la media de importancia (para que 0 = bajo, 2 = alto)
cluster_order = importance_df.groupby("cluster")["mean_importance"].mean().sort_values().index
mapping = {old:new for new, old in enumerate(cluster_order)}
importance_df["cluster"] = importance_df["cluster"].map(mapping)

# Dibujar gráfico
plt.figure(figsize=(8,6))
plt.scatter(range(len(importance_df)), importance_df["mean_importance"], 
            c=importance_df["cluster"], cmap="viridis", s=50)
plt.xlabel("Features (ordenadas)")
plt.ylabel("Importancia media")
plt.title("Clusterización de importancias (KMeans)")
plt.colorbar(label="Clúster (0=bajo, 1=medio, 2=alto)")
plt.show()

# Seleccionar las características del clúster con más importancia media
kmeans_selected_features = importance_df[importance_df["cluster"] == 2]["feature"].tolist()
print(f"{len(kmeans_selected_features)} features seleccionadas:", kmeans_selected_features)
# Out:
# 14 features seleccionadas: ['CHEK1', 'IKZF3', 'ASPM', 'CAMK1D', 'FNDC3B', 'EHF', 'RSU1', 'EML4', 'GTF2A1', 'CCND2', 'RNF19A', 'CDT1', 'MAD2L1', 'UBE2S']

# %%
# Selección de las features indicadas según el método que más
# se haya acercado al número de referencia de 20 características.
reference_value = 20

# Calcular las diferencias con respecto al valor de referencia
diff_elbow = abs(len(elbow_selected_features) - reference_value)
diff_kmeans = abs(len(kmeans_selected_features) - reference_value)

# Seleccionar la lista de features con menor diferencia
if diff_elbow <= diff_kmeans:
    feature_selection_method = "elbow"
    selected_features = elbow_selected_features
else:
    feature_selection_method = "kmeans"
    selected_features = kmeans_selected_features

print(f"Se seleccionan las features según el método de {feature_selection_method}"
      f"\n\n{len(selected_features)} features: {selected_features}")
# Out:
# Se seleccionan las features según el método de elbow
#
# 24 features: ['CHEK1', 'IKZF3', 'ASPM', 'CAMK1D', 'FNDC3B', 'EHF', 'RSU1', 'EML4', 'GTF2A1', 'CCND2', 'RNF19A', 'CDT1', 'MAD2L1', 'UBE2S', 'EEA1', 'CRIPT', 'KLHL7', 'RAB28', 'CCNK', 'LUM', 'PLXDC2', 'CDK6', 'ACADSB', 'DTWD1']

# %% [markdown]
# #### 1.5 Creación de los datasets finales con las características selecionadas

# %% [markdown]
# Por si en otro momento se quieren probar otros análisis, con los datasets con las características seleccionadas se crearán versiones finales del dataset completo original, todos los subconjuntos usados y todos los subconjuntos escalados.
#
# **NOTA**: Esto también valdrá en caso de que por cualquier problema de aleatorización el presente notebook deje de tener datos coherentes con el estudio. Estos ficheros creados aquí deberán valer para continuar el estudio a partir de este punto como copia de seguridad.

# %%
# Definir las columnas finales
final_columns = selected_features + ["Sample_id", "Response"]

# Crear versiones finales de cada dataset
df_full_final = df_full[final_columns].copy()

df_train_final = df_train[final_columns].copy()
df_test_final = df_test[final_columns].copy()
df_cal_final = df_cal[final_columns].copy()

df_scaled_train_final = df_scaled_train[final_columns].copy()
df_scaled_test_final = df_scaled_test[final_columns].copy()
df_scaled_cal_final = df_scaled_cal[final_columns].copy()

# Mostrar ejemplo de dataset final
print("Train final shape:", df_train_final.shape)
print("Test final shape:", df_test_final.shape)
df_train_final.head()
# Out:
# Train final shape: (1416, 26)
# Test final shape: (284, 26)
#       CHEK1     IKZF3      ASPM    CAMK1D     FNDC3B       EHF       RSU1  \
# 0  8.972392  8.187603  8.998980  9.098783  10.668240  9.410645  11.374427
# 1  5.384497  3.553094  4.530663  5.244795   7.540913  3.668030   7.170936
# 2  7.156831  7.138752  6.956739  8.292189   8.756135  6.517143   7.190598
# 3  6.493792  5.042115  6.404509  5.972260   6.809599  8.505280   8.861336
# 4  4.172403  3.463043  5.206810  4.566977   5.554162  3.611113   6.745759
#
#        EML4    GTF2A1      CCND2  ...      KLHL7     RAB28      CCNK  \
# 0  9.384072  9.600273  11.146514  ...  10.484633  9.731618  9.164413
# 1  5.162887  4.770363   5.766927  ...   4.404214  4.204025  5.119094
# 2  7.476863  9.081633   8.875050  ...   7.207713  7.059732  8.137091
# 3  7.048676  7.230153   6.130298  ...   5.013088  4.885525  7.301955
# 4  5.933522  5.222132   6.062487  ...   4.640900  4.543771  5.331784
#
#          LUM    PLXDC2      CDK6    ACADSB     DTWD1       Sample_id  \
# 0  11.223811  8.037716  8.957033  8.356812  7.843515       GSM158252
# 1   7.465366  3.638012  5.278336  5.431514  4.252184       GSM508120
# 2   6.468456  7.986558  6.517143  7.453805  7.290351      GSM2804900
# 3   7.562437  5.752369  6.556013  5.120521  5.985743  GSM2193370--22
# 4   5.228613  3.742715  4.478539  4.743829  4.259315       GSM505471
#
#        Response
# 0      Response
# 1  Non_response
# 2      Response
# 3      Response
# 4  Non_response
#
# [5 rows x 26 columns]

# %% [markdown]
# Para rematar los datasets finales y guardarlos, primero conviene hacer alguna comprobación de integridad, estar seguros de que no se ha cometido algún error a la hora de manipular columnas, fusionar datos, etc.
#
# La siguiente función comprueba si para el dataset original y el dataset final, la misma combinación de gen y sample_id siguen teniendo el mismo valor en ambos casos. Esa prueba se repite 'n' veces.

# %%
import numpy as np

def check_df_consistency(df_original, df_final, n=100):
    """
    Comprueba aleatoriamente si los valores coinciden entre df_original y df_final
    para las mismas combinaciones de Sample_id y columna (gen).
    
    Parámetros
    ----------
    df_original : pandas dataframe
        DataFrame completo
    df_final : pandas dataframe
        DataFrame reducido (con Sample_id, Response y features seleccionadas)
    n : int
        número de comprobaciones aleatorias
    
    Imprime
    -------
    Los primeros 5 resultados de la comprobación
    
    Un mensaje final de éxito o fracaso
    """
    
    # Columnas que están en el dataset final (excluyendo Sample_id y Response)
    columnas_finales = [c for c in df_final.columns if c not in ["Sample_id", "Response"]]
    
    # Sample_ids presentes en df_final
    sample_ids = df_final["Sample_id"].unique()
    
    resultados = []
    
    for _ in range(n):
        # Elegir aleatoriamente un sample_id y una columna
        sample_id = rng.choice(sample_ids)
        col = rng.choice(columnas_finales)
        
        # Obtener valores
        orig_value = df_original.loc[df_original["Sample_id"] == sample_id, col].iloc[0]
        final_value = df_final.loc[df_final["Sample_id"] == sample_id, col].iloc[0]
        
        is_match = (orig_value == final_value)
        
        resultados.append(
            (str(sample_id), str(col), float(orig_value), float(final_value), bool(is_match)))
    
    # Mostrar solo los primeros 5
    print("Primeras 5 comprobaciones:")
    for r in resultados[:5]:
        print(r)
    
    # Mostrar mensaje final
    if all(r[-1] for r in resultados):
        print("\n##ÉXITO##: Verificación completada: todos los valores coinciden.\n-------\n")
    else:
        print("\nWARNING!! Inconsistencias detectadas: algunos valores no coinciden.")

# %%
# Comprobación de 1000 datos aleatorios entre datasets iniciales y finales
check_df_consistency(df_full, df_full_final, n=1000)
check_df_consistency(df_train, df_train_final, n=1000)
check_df_consistency(df_test, df_test_final, n=1000)
check_df_consistency(df_cal, df_cal_final, n=1000)
check_df_consistency(df_scaled_train, df_scaled_train_final, n=1000)
check_df_consistency(df_scaled_test, df_scaled_test_final, n=1000)
check_df_consistency(df_scaled_cal, df_scaled_cal_final, n=1000)
# Out:
# Primeras 5 comprobaciones:
# ('GSM1875945', 'FNDC3B', 10.255631589544, 10.255631589544, True)
# ('GSM1875993', 'EEA1', 9.44216279713417, 9.44216279713417, True)
# ('GSM1233132', 'MAD2L1', 3.37346952656649, 3.37346952656649, True)
# ('GSM505423', 'RAB28', 3.537721458, 3.537721458, True)
# ('GSM505426', 'EML4', 5.254229933, 5.254229933, True)
#
# ##ÉXITO##: Verificación completada: todos los valores coinciden.
# -------
#
# Primeras 5 comprobaciones:
# ('GSM2804986', 'MAD2L1', 6.94141896, 6.94141896, True)
# ('GSM158252', 'ACADSB', 8.35681150437948, 8.35681150437948, True)
# ('GSM1619454', 'CCNK', 9.29138753865069, 9.29138753865069, True)
# ('GSM508120', 'CCNK', 5.119093657, 5.119093657, True)
# ('GSM1875942', 'KLHL7', 9.0822000438932, 9.0822000438932, True)
#
# ##ÉXITO##: Verificación completada: todos los valores coinciden.
# -------
#
# Primeras 5 comprobaciones:
# ('GSM505385', 'ACADSB', 4.091508089, 4.091508089, True)
# ('GSM1050611', 'CDK6', 5.62167668546684, 5.62167668546684, True)
# ('GSM1233029', 'FNDC3B', 6.61975151248692, 6.61975151248692, True)
# ('GSM139601', 'CCNK', 9.354682, 9.354682, True)
# ('GSM1875919', 'KLHL7', 8.6163719092545, 8.6163719092545, True)
#
# ##ÉXITO##: Verificación completada: todos los valores coinciden.
# -------
#
# Primeras 5 comprobaciones:
# ('GSM590874', 'ACADSB', 3.527344756, 3.527344756, True)
# ('GSM590853', 'LUM', 7.210503997, 7.210503997, True)
# ('GSM139562', 'CDK6', 9.05783, 9.05783, True)
# ('GSM508109', 'PLXDC2', 4.689361761, 4.689361761, True)
# ('GSM158203', 'LUM', 12.3673139411334, 12.3673139411334, True)
#
# ##ÉXITO##: Verificación completada: todos los valores coinciden.
# -------
#
# Primeras 5 comprobaciones:
# ('GSM508188', 'GTF2A1', -1.1979363270159953, -1.1979363270159953, True)
# ('GSM1233132', 'CHEK1', -0.8174376071675491, -0.8174376071675491, True)
# ('GSM2804847', 'LUM', -0.4549609330265469, -0.4549609330265469, True)
# ('GSM1050666', 'ASPM', -0.7031523256995342, -0.7031523256995342, True)
# ('GSM1619409', 'GTF2A1', 0.912763155504547, 0.912763155504547, True)
#
# ##ÉXITO##: Verificación completada: todos los valores coinciden.
# -------
#
# Primeras 5 comprobaciones:
# ('GSM1619438', 'CAMK1D', 0.7271317952208507, 0.7271317952208507, True)
# ('GSM107986', 'EHF', 0.8193670048507942, 0.8193670048507942, True)
# ('GSM1875979', 'LUM', 0.5187945970003243, 0.5187945970003243, True)
# ('GSM710845', 'CDK6', 1.2475131448146604, 1.2475131448146604, True)
# ('GSM505330', 'FNDC3B', -1.5670900872969458, -1.5670900872969458, True)
#
# ##ÉXITO##: Verificación completada: todos los valores coinciden.
# -------
#
# Primeras 5 comprobaciones:
# ('GSM1875914', 'CCND2', 1.0632466390258468, 1.0632466390258468, True)
# ('GSM1525234--211', 'CHEK1', 0.9379273433995563, 0.9379273433995563, True)
# ('GSM139603', 'GTF2A1', 1.0224139160353674, 1.0224139160353674, True)
# ('GSM505352', 'CHEK1', -1.1275321031517078, -1.1275321031517078, True)
# ('GSM508143', 'LUM', -0.7251604931241068, -0.7251604931241068, True)
#
# ##ÉXITO##: Verificación completada: todos los valores coinciden.
# -------

# %% [markdown]
# Llegados a este punto ya se pueden guardar los datasets finales

# %%
# Guardamos los datasets
df_full_final.to_csv("./data/final/full_top_significance_reduced_feat.csv", index=False)
df_train_final.to_csv("./data/final/train_reduced_feat.csv", index=False)
df_test_final.to_csv("./data/final/test_reduced_feat.csv", index=False)
df_cal_final.to_csv("./data/final/cal_reduced_feat.csv", index=False)
df_scaled_train_final.to_csv("./data/final/scaled_train_reduced_feat.csv", index=False)
df_scaled_test_final.to_csv("./data/final/scaled_test_reduced_feat.csv", index=False)
df_scaled_cal_final.to_csv("./data/final/scaled_cal_reduced_feat.csv", index=False)
